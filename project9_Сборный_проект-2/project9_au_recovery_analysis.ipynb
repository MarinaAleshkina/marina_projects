# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Изучение-имеющихся-данных-по-выборкам" data-toc-modified-id="Изучение-имеющихся-данных-по-выборкам-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Изучение имеющихся данных по выборкам</a></span></li><li><span><a href="#Расчет-эффективности-обогащения" data-toc-modified-id="Расчет-эффективности-обогащения-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Расчет эффективности обогащения</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Предобработка данных</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изменение-концентрации-металлов-(Au,-Ag,-Pb)-на-различных-этапах" data-toc-modified-id="Изменение-концентрации-металлов-(Au,-Ag,-Pb)-на-различных-этапах-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Изменение концентрации металлов (Au, Ag, Pb) на различных этапах</a></span></li><li><span><a href="#Сравнение-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках" data-toc-modified-id="Сравнение-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Сравнение распределения размеров гранул сырья на обучающей и тестовой выборках</a></span></li><li><span><a href="#Исследование-суммарной-концентрации-всех-веществ-на-разных-стадиях" data-toc-modified-id="Исследование-суммарной-концентрации-всех-веществ-на-разных-стадиях-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Исследование суммарной концентрации всех веществ на разных стадиях</a></span></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><span><a href="#Подготовка-признаков-и-целевых-значений" data-toc-modified-id="Подготовка-признаков-и-целевых-значений-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Подготовка признаков и целевых значений</a></span></li><li><span><a href="#Функция-вычисления-целевой-метрики-sMAPE" data-toc-modified-id="Функция-вычисления-целевой-метрики-sMAPE-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Функция вычисления целевой метрики sMAPE</a></span></li><li><span><a href="#Подбор-наилучшей-модели-на-обучающей-выборке" data-toc-modified-id="Подбор-наилучшей-модели-на-обучающей-выборке-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Подбор наилучшей модели на обучающей выборке</a></span><ul class="toc-item"><li><span><a href="#Модель-решающего-дерева" data-toc-modified-id="Модель-решающего-дерева-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Модель решающего дерева</a></span></li><li><span><a href="#Модель-случайного-леса" data-toc-modified-id="Модель-случайного-леса-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Модель случайного леса</a></span></li><li><span><a href="#Модель-Лассо" data-toc-modified-id="Модель-Лассо-3.3.3"><span class="toc-item-num">3.3.3&nbsp;&nbsp;</span>Модель Лассо</a></span></li><li><span><a href="#Ридж-регрессия" data-toc-modified-id="Ридж-регрессия-3.3.4"><span class="toc-item-num">3.3.4&nbsp;&nbsp;</span>Ридж регрессия</a></span></li><li><span><a href="#Dummy-регрессор" data-toc-modified-id="Dummy-регрессор-3.3.5"><span class="toc-item-num">3.3.5&nbsp;&nbsp;</span>Dummy регрессор</a></span></li><li><span><a href="#Проверка-выбранной-модели-на-тестовых-данных" data-toc-modified-id="Проверка-выбранной-модели-на-тестовых-данных-3.3.6"><span class="toc-item-num">3.3.6&nbsp;&nbsp;</span>Проверка выбранной модели на тестовых данных</a></span></li></ul></li></ul></li><li><span><a href="#Итоговый-вывод" data-toc-modified-id="Итоговый-вывод-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Итоговый вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Подготовьте прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Вам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.
#
# Чтобы выполнить проект, обращайтесь к библиотекам *pandas*, *matplotlib* и *sklearn.* Вам поможет их документация.

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Изучение имеющихся данных по выборкам

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import make_scorer
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Lasso, Ridge
from sklearn.dummy import DummyRegressor
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Загрузим обучающую и тестовую выборки, а также полный набор данных.

# %%
try:
    data_train =pd.read_csv(r'C:\Users\Марина\Downloads\gold_recovery_train_new.csv')
    data_test = pd.read_csv(r'C:\Users\Марина\Downloads\gold_recovery_test_new.csv')
    data_full = pd.read_csv(r'C:\Users\Марина\Downloads\gold_recovery_full_new.csv')
except:
    data_train = pd.read_csv('https://code.s3.yandex.net/datasets/gold_recovery_train_new.csv')
    data_test = pd.read_csv('https://code.s3.yandex.net/datasets/gold_recovery_test_new.csv')
    data_full = pd.read_csv('https://code.s3.yandex.net/datasets/gold_recovery_full_new.csv')

# %% [markdown]
# Посмотрим на первые 10 строк каждой из выборок, сравним имеющиеся данные.

# %%
data_train.head(10)
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
# 5  2016-01-15 05:00:00                     6.482968
# 6  2016-01-15 06:00:00                     6.533849
# 7  2016-01-15 07:00:00                     6.130823
# 8  2016-01-15 08:00:00                     5.834140
# 9  2016-01-15 09:00:00                     5.687063
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
# ...

# %%
data_test.head(10)
# Out:
#                   date  primary_cleaner.input.sulfate  \
# 0  2016-09-01 00:59:59                     210.800909
# 1  2016-09-01 01:59:59                     215.392455
# 2  2016-09-01 02:59:59                     215.259946
# 3  2016-09-01 03:59:59                     215.336236
# 4  2016-09-01 04:59:59                     199.099327
# 5  2016-09-01 05:59:59                     168.485085
# 6  2016-09-01 06:59:59                     144.133440
# 7  2016-09-01 07:59:59                     133.513396
# 8  2016-09-01 08:59:59                     133.735356
# 9  2016-09-01 09:59:59                     126.961069
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                         14.993118                         8.080000
# 1                         14.987471                         8.080000
# 2                         12.884934                         7.786667
# 3                         12.006805                         7.640000
# ...

# %%
data_full.head(10)
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
# 5  2016-01-15 05:00:00                     6.482968
# 6  2016-01-15 06:00:00                     6.533849
# 7  2016-01-15 07:00:00                     6.130823
# 8  2016-01-15 08:00:00                     5.834140
# 9  2016-01-15 09:00:00                     5.687063
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
# ...

# %% [markdown]
# В обучающей выборке сохранен весь набор признаков и целевых значений из полной выборки, в тестовую часть попали только 53 признака. Нет целевых значений и также удалены те признаки, к которым, вероятно,
# не будет доступа в реальной жизни при запуске модели.
# Посмотрим,какие из признаков не были включены в тестовую часть.

# %%
missing = []
for column in data_train.columns:
    if column not in data_test.columns:
        missing.append(column)

print(missing)
print()
print(len(missing))
# Out:
# ['final.output.concentrate_ag', 'final.output.concentrate_pb', 'final.output.concentrate_sol', 'final.output.concentrate_au', 'final.output.recovery', 'final.output.tail_ag', 'final.output.tail_pb', 'final.output.tail_sol', 'final.output.tail_au', 'primary_cleaner.output.concentrate_ag', 'primary_cleaner.output.concentrate_pb', 'primary_cleaner.output.concentrate_sol', 'primary_cleaner.output.concentrate_au', 'primary_cleaner.output.tail_ag', 'primary_cleaner.output.tail_pb', 'primary_cleaner.output.tail_sol', 'primary_cleaner.output.tail_au', 'rougher.calculation.sulfate_to_au_concentrate', 'rougher.calculation.floatbank10_sulfate_to_au_feed', 'rougher.calculation.floatbank11_sulfate_to_au_feed', 'rougher.calculation.au_pb_ratio', 'rougher.output.concentrate_ag', 'rougher.output.concentrate_pb', 'rougher.output.concentrate_sol', 'rougher.output.concentrate_au', 'rougher.output.recovery', 'rougher.output.tail_ag', 'rougher.output.tail_pb', 'rougher.output.tail_sol', 'rougher.output.t
# ...

# %% [markdown]
# Отсутсвуют признаки с типами параметров переменных output и calculation. Output - выходные данные после этапов технологического процесса, calculation - расчетные метрики, в которых используются output-ы.

# %% [markdown]
# Посмотрим на основную информацию по имеющимся выборкам.

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14149 entries, 0 to 14148
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                14149 non-null  object
#  1   final.output.concentrate_ag                         14148 non-null  float64
#  2   final.output.concentrate_pb                         14148 non-null  float64
#  3   final.output.concentrate_sol                        13938 non-null  float64
#  4   final.output.concentrate_au                         14149 non-null  float64
#  5   final.output.recovery                               14149 non-null  float64
#  6   final.output.tail_ag                                14149 non-null  float64
#  7   final.output.tail_pb                                14049 non-null  float64
# ...

# %%
data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5290 entries, 0 to 5289
# Data columns (total 53 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        5290 non-null   object
#  1   primary_cleaner.input.sulfate               5286 non-null   float64
#  2   primary_cleaner.input.depressant            5285 non-null   float64
#  3   primary_cleaner.input.feed_size             5290 non-null   float64
#  4   primary_cleaner.input.xanthate              5286 non-null   float64
#  5   primary_cleaner.state.floatbank8_a_air      5290 non-null   float64
#  6   primary_cleaner.state.floatbank8_a_level    5290 non-null   float64
#  7   primary_cleaner.state.floatbank8_b_air      5290 non-null   float64
#  8   primary_cleaner.state.floatbank8_b_level    5290 non-null   float64
# ...

# %%
data_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                19439 non-null  object
#  1   final.output.concentrate_ag                         19438 non-null  float64
#  2   final.output.concentrate_pb                         19438 non-null  float64
#  3   final.output.concentrate_sol                        19228 non-null  float64
#  4   final.output.concentrate_au                         19439 non-null  float64
#  5   final.output.recovery                               19439 non-null  float64
#  6   final.output.tail_ag                                19438 non-null  float64
#  7   final.output.tail_pb                                19338 non-null  float64
# ...

# %% [markdown]
# ### Расчет эффективности обогащения

# %% [markdown]
# Проверим, верно ли рассчитана эффективность обогащения. Вычислим её на обучающей выборке для признака rougher.output.recovery. Найдем MAE между расчетным показателем и  фактическим значением признака.

# %%
C = data_train['rougher.output.concentrate_au']
F = data_train['rougher.input.feed_au']
T = data_train['rougher.output.tail_au']

recovery = (C*(F-T)) /(F*(C-T))*100

# %%
MAE = mean_absolute_error(data_train['rougher.output.recovery'], recovery)
print(MAE)
# Out:
# 9.73512347450521e-15

# %% [markdown]
# Значение средней абсолютной ошибки очень мало, это говорит о том, расчетное значение совпадает с фактически имеющимися данными.

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# Проанализируем пропущенные значения в обучающей и тестовой выборках.

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(data_train.isna().sum().sort_values(ascending=False))
# Out:
# secondary_cleaner.output.tail_sol                     1605
# rougher.state.floatbank10_e_air                        436
# rougher.input.floatbank11_xanthate                     428
# primary_cleaner.output.concentrate_sol                 286
# secondary_cleaner.state.floatbank2_a_air               217
# final.output.concentrate_sol                           211
# rougher.input.feed_size                                144
# primary_cleaner.input.xanthate                         100
# rougher.input.feed_pb                                  100
# final.output.tail_pb                                   100
# primary_cleaner.output.concentrate_pb                   86
# rougher.input.feed_sol                                  78
# primary_cleaner.output.tail_sol                         46
# rougher.input.floatbank11_sulfate                       36
# primary_cleaner.input.depressant                        32
# rougher.input.floatbank10_sulfate                       29
# ...

# %% [markdown]
# Исходя из информации о том, что соседние значения зачастую похожи, заполним пропуски методом ffil с максимальным лимитом 24 (то есть сутки, так как замеры производятся каждый час).

# %%
data_train = data_train.fillna(method='ffill', limit=24)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(data_train.isna().sum().sort_values(ascending=False))
# Out:
# secondary_cleaner.output.tail_sol                     409
# rougher.state.floatbank10_e_air                       309
# rougher.input.floatbank11_xanthate                    246
# secondary_cleaner.state.floatbank2_a_air               75
# rougher.input.feed_size                                59
# final.output.tail_pb                                    8
# rougher.input.feed_pb                                   8
# rougher.state.floatbank10_b_level                       0
# rougher.state.floatbank10_e_level                       0
# rougher.state.floatbank10_d_level                       0
# rougher.state.floatbank10_d_air                         0
# rougher.state.floatbank10_c_level                       0
# rougher.state.floatbank10_c_air                         0
# rougher.state.floatbank10_a_level                       0
# rougher.state.floatbank10_b_air                         0
# rougher.state.floatbank10_f_level                       0
# ...

# %% [markdown]
# Оставшиеся пропуски удалим из выборки.

# %%
data_train = data_train.dropna().reset_index(drop=True)

# %%
data_train.shape
# Out:
# (13083, 87)

# %% [markdown]
# Потеря данных составила 7,5%

# %% [markdown]
# Аналогичную обработку пропусков проведем на тестовой выборке.

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(data_test.isna().sum().sort_values(ascending=False))
# Out:
# rougher.input.floatbank11_xanthate            25
# rougher.input.feed_sol                        21
# secondary_cleaner.state.floatbank3_a_air       9
# rougher.input.floatbank11_sulfate              8
# primary_cleaner.input.depressant               5
# rougher.input.floatbank10_sulfate              5
# primary_cleaner.input.xanthate                 4
# primary_cleaner.input.sulfate                  4
# rougher.input.feed_rate                        3
# secondary_cleaner.state.floatbank2_a_air       3
# secondary_cleaner.state.floatbank2_b_air       2
# rougher.input.feed_size                        1
# secondary_cleaner.state.floatbank2_b_level     0
# rougher.state.floatbank10_f_level              0
# rougher.state.floatbank10_f_air                0
# secondary_cleaner.state.floatbank3_a_level     0
# secondary_cleaner.state.floatbank2_a_level     0
# date                                           0
# rougher.state.floatbank10_e_air                0
# ...

# %%
data_test = data_test.fillna(method='ffill', limit=24)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(data_test.isna().sum().sort_values(ascending=False))
# Out:
# date                                          0
# rougher.state.floatbank10_c_air               0
# rougher.state.floatbank10_d_air               0
# rougher.state.floatbank10_d_level             0
# rougher.state.floatbank10_e_air               0
# rougher.state.floatbank10_e_level             0
# rougher.state.floatbank10_f_air               0
# rougher.state.floatbank10_f_level             0
# secondary_cleaner.state.floatbank2_a_air      0
# secondary_cleaner.state.floatbank2_a_level    0
# secondary_cleaner.state.floatbank2_b_air      0
# secondary_cleaner.state.floatbank2_b_level    0
# secondary_cleaner.state.floatbank3_a_air      0
# secondary_cleaner.state.floatbank3_a_level    0
# secondary_cleaner.state.floatbank3_b_air      0
# secondary_cleaner.state.floatbank3_b_level    0
# secondary_cleaner.state.floatbank4_a_air      0
# secondary_cleaner.state.floatbank4_a_level    0
# secondary_cleaner.state.floatbank4_b_air      0
# secondary_cleaner.state.floatbank4_b_level    0
# ...

# %% [markdown]
# Проверим данные на наличие явных дубликатов (например, в случае, если какие-то данные на определенный момент времени ввели случайно несколько раз).

# %%
data_train.duplicated().sum()
# Out:
# 0

# %%
data_test.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Явные дубликаты не обнаружены.

# %% [markdown]
# Посмотрим на коэффициенты корреляции Пирсона между признаками.

# %%
data_train.drop(['date','rougher.output.recovery', 'final.output.recovery'], axis=1). corr()
# Out:
#                                             final.output.concentrate_ag  \
# final.output.concentrate_ag                                    1.000000
# final.output.concentrate_pb                                    0.024849
# final.output.concentrate_sol                                   0.296319
# final.output.concentrate_au                                   -0.125882
# final.output.tail_ag                                           0.301035
# ...                                                                 ...
# secondary_cleaner.state.floatbank5_a_level                     0.222502
# secondary_cleaner.state.floatbank5_b_air                       0.021989
# secondary_cleaner.state.floatbank5_b_level                     0.191931
# secondary_cleaner.state.floatbank6_a_air                       0.166538
# secondary_cleaner.state.floatbank6_a_level                     0.064135
#
#                                             final.output.concentrate_pb  \
# ...

# %%
data_test.drop(['date'], axis=1). corr()
# Out:
#                                             primary_cleaner.input.sulfate  \
# primary_cleaner.input.sulfate                                    1.000000
# primary_cleaner.input.depressant                                 0.452138
# primary_cleaner.input.feed_size                                  0.114564
# primary_cleaner.input.xanthate                                   0.496786
# primary_cleaner.state.floatbank8_a_air                           0.100810
# primary_cleaner.state.floatbank8_a_level                         0.047802
# primary_cleaner.state.floatbank8_b_air                           0.074719
# primary_cleaner.state.floatbank8_b_level                         0.139819
# primary_cleaner.state.floatbank8_c_air                           0.024925
# primary_cleaner.state.floatbank8_c_level                         0.028155
# primary_cleaner.state.floatbank8_d_air                           0.093636
# primary_cleaner.state.floatbank8_d_level                        -0.019008
# ...

# %% [markdown]
# Присутствует мультиколлинеарность признаков, соответственно при моделировании необходимо будет принять это во внимание,
# использовать линейные модели регрессии с регуляризацией, либо модели случайного леса или решаюшего дерева.

# %% [markdown]
# <div class="alert alert-info">
# <b> ВЫВОД:</b>
# На данном этапе проведено изучение данных имеющихся выборок.
#
# 1. Выявлены следующие закономерности:
#     - количество признаков в обучающей и тестовой выборках различно
#     - в тестовой выборке отсутствуют целевые признаки
#     - в данных присутсвуют пропуски
# 2. Проведен расчет эффективности обогащения. MAE между расчетным показателем и фактическим значением признака очень мала, что говорит о корректности имеющихся данных.
# 3. Осуществлена предобработка данных:
#     - часть пропусков заполнено, часть удалено из выборки
#     - осуществлена проверка на явные дубликаты,они не обнаружены
#     - проведена проверка на мультиколлинеарность, некоторые признаки сильно коррелируют между собой, в связи с этим в будущем будем пользоваться линейными моделями с регуляризацией.
#
# Данные изучены, подготовлены к дальнейшему исследованию.
#
#
# </div>

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Изменение концентрации металлов (Au, Ag, Pb) на различных этапах

# %% [markdown]
# Изучим, как меняется концентрация золота (Au) на различных этапах очистки.
#
# Этапы:
# rougher — флотация
# primary_cleaner — первичная очистка
# secondary_cleaner — вторичная очистка
# final — финальные характеристики

# %%
plt.figure(figsize=[10,12])

plt.hist(data_full['rougher.input.feed_au'], bins=50, label = 'флотация_подача_сырья', alpha=.5)
plt.hist(data_full['rougher.output.concentrate_au'], bins=50, label = 'флотация_выход', alpha=.5)
plt.hist(data_full['primary_cleaner.output.concentrate_au'], bins=50, label = 'первичная очистка_выход', alpha=.5)
plt.hist(data_full['final.output.concentrate_au'], bins=50, label = 'финальный_выход_сырья', alpha=.5)

plt.grid()
plt.xlim([0, 55])
plt.ylim([0, 4010])
plt.legend()
plt.title('Изменение концентрации золота на различных этапах технологического процесса')
plt.show()

# %% [markdown]
# Концентрация золота увеличивается от этапа к этапу и достигает максимума на финальной стадии. Поскольку технологического процесса является добыча золота из руды,
# то можно сказать, что увелечение концентрации Ag логично.
# По графикам распределение также видны нулевые значения контрации на каждом из этапов, уделим внимание этим данным далее.

# %% [markdown]
# Изучим, как меняется концентрация серебра (Ag) на различных этапах.

# %%
plt.figure(figsize=[10,12])

plt.hist(data_full['rougher.input.feed_ag'], bins=50, label = 'флотация_подача_сырья', alpha=0.5)
plt.hist(data_full['rougher.output.concentrate_ag'], bins=50, label = 'флотация_выход', alpha=0.5)
plt.hist(data_full['primary_cleaner.output.concentrate_ag'], bins=50, label = 'первичная очистка_выход', alpha=0.5)
plt.hist(data_full['final.output.concentrate_ag'], bins=50, label = 'финальный_выход_сырья', alpha=0.5)

plt.grid()
plt.xlim([0, 20])
plt.ylim([0, 2000])
plt.legend()
plt.title('Изменение концентрации серебра на различных этапах технологического процесса')
plt.show()

# %% [markdown]
# Концентрация серебра в руде увеличивается после флотации, а затем уменьшается от этапа к этапу.
# Увеличение концентрации серебра после флотации, вероятно, связано с особенностями реализации самого процесса обогащения руды.
# Затем в ходе первичной и вторичной очистки вместе с увеличением концентрации основного металла - золота, уменьшается доля других металлов.
#
# Также присутствуют нулевые концентрации.

# %% [markdown]
# Изучим, как меняется концентрация свинца (Pb) на различных этапах.

# %%
plt.figure(figsize=[12,12])

plt.hist(data_full['rougher.input.feed_pb'], bins=50, label = 'флотация_подача_сырья', alpha=0.5)
plt.hist(data_full['rougher.output.concentrate_pb'], bins=50, label = 'флотация_выход', alpha=0.5)
plt.hist(data_full['primary_cleaner.output.concentrate_pb'], bins=50, label = 'первичная очистка_выход', alpha=0.5)
plt.hist(data_full['final.output.concentrate_pb'], bins=50, label = 'финальный_выход_сырья', alpha=0.5)

plt.grid()
plt.xlim([0, 18])
plt.ylim([0, 2000])
plt.legend()
plt.title('Изменение концентрации свинца на различных этапах технологического процесса')
plt.show()

# %% [markdown]
# Судя по распределению доли свинца в руде, до первичной очистки она растет, затем стабилизируется.
# Также присутствуют нулевые значения концентраций.

# %% [markdown]
# ### Сравнение распределения размеров гранул сырья на обучающей и тестовой выборках

# %% [markdown]
# Сравним распределение размеров гранул сырья в тестовой и обучающей выборке до флотации.

# %%
# строим нормированные гистограммы rougher.input.feed_size для каждой из выборок 
plt.figure(figsize=[12,8])

plt.hist(data_train['rougher.input.feed_size'], density = True, bins=100, label = 'train', alpha=0.5)
plt.hist(data_test['rougher.input.feed_size'], density = True, bins=100, label = 'test', alpha=0.5)

plt.grid()
plt.legend()
plt.title('Распределение размера гранул сырья до флотации')
plt.show()

# %% [markdown]
# Распределения схожи, тестовая выборка имеет один ярко выраженный пик. Есть выбросы. Распределения скошены влево для обеих выборок.

# %% [markdown]
# Сравним распределение размеров гранул сырья в тестовой и обучающей выборке после вторичной очистки.

# %%
# строим нормированные гистограммы primary_cleaner.input.feed_size для каждой из выборок 
plt.figure(figsize=[12,8])

plt.hist(data_train['primary_cleaner.input.feed_size'], density = True, bins=100, label = 'train', alpha=0.5)
plt.hist(data_test['primary_cleaner.input.feed_size'], density = True, bins=100, label = 'test', alpha=0.5)

plt.grid()
plt.legend()
plt.title('Распределение размера гранул сырья после вторичной очистки')
plt.show()

# %% [markdown]
# Распределения схожи и близки к нормальному.

# %% [markdown]
# ### Исследование суммарной концентрации всех веществ на разных стадиях

# %% [markdown]
# Рассмотрим концентрацию веществ на разных стадиях:
#  - в сырье (rougher.input.feed)
#  - в черновом концентрате (rougher.output.concentrate)
#  - в финальном концентрате (final.output.concentrate)

# %%
#создадим новые столбцы датафреймов с сумарными концентрациями веществ по известным признакам
data_train['rougher_input_feed'] = data_train['rougher.input.feed_ag'] + data_train['rougher.input.feed_pb'] + \
                            data_train['rougher.input.feed_sol'] + data_train['rougher.input.feed_au']

data_test['rougher_input_feed_test'] = data_test['rougher.input.feed_ag'] + data_test['rougher.input.feed_pb'] + \
                            data_test['rougher.input.feed_sol'] + data_test['rougher.input.feed_au']

data_train['rougher_output_concentrate'] = data_train['rougher.output.concentrate_ag'] + data_train['rougher.output.concentrate_pb'] + \
                            data_train['rougher.output.concentrate_sol'] + data_train['rougher.output.concentrate_au']

data_train['final_output_concentrate'] = data_train['final.output.concentrate_ag'] + data_train['final.output.concentrate_pb'] + \
                            data_train['final.output.concentrate_sol'] + data_train['final.output.concentrate_au']

# %% [markdown]
# Посмотрим на распределения полученных суммарных концентраций.

# %%
list = [data_train['rougher_input_feed'], data_test['rougher_input_feed_test'], data_train['rougher_output_concentrate'], \
        data_train['final_output_concentrate'] ]
for elem in list:
    elem.hist(figsize =(14,10), legend=True, grid=True, bins=100)

# %% [markdown]
# Согласно распределениям величин, наблюдаем всплеск нулевых и околонулевых значений. Эти данные можно считать выбросами, которые могут негативно сказаться на качестве будущей модели. Рассмотрим отдельно каждую величину, построим гистограмму распределения и диаграмму размаха. Удалим явные выбросы.

# %%
#функция для вывода описательной статистики и построения необходимых графиков

def data_analysis(data):
    describe = data.describe()
    print(describe)
    fig, ax = plt.subplots(1,2, figsize=(18,8))
    data.plot(kind='hist', title = data.name, ylabel = 'frequency', bins=100,grid=True, ax=ax[0])
    data.plot(kind = 'box', title= data.name, grid=True,ax=ax[1])
    plt.show()

# %%
data_analysis(data_train['rougher_input_feed'])
# Out:
# count    13083.000000
# mean        56.325249
# std          6.992904
# min          0.040000
# 25%         52.659171
# 50%         56.697114
# 75%         60.863844
# max         73.668306
# Name: rougher_input_feed, dtype: float64

# %%
data_train = data_train[data_train['rougher_input_feed']>30]

# %%
data_analysis(data_test['rougher_input_feed_test'])
# Out:
# count    5290.000000
# mean       60.205741
# std         6.896581
# min         4.501868
# 25%        56.458730
# 50%        59.999831
# 75%        65.099348
# max        76.978947
# Name: rougher_input_feed_test, dtype: float64

# %%
data_test = data_test[data_test['rougher_input_feed_test']>30]

# %%
data_analysis(data_train['rougher_output_concentrate'])
# Out:
# count    13016.000000
# mean        67.461423
# std         12.275633
# min          0.000000
# 25%         65.055729
# 50%         69.270031
# 75%         73.553153
# max         88.140119
# Name: rougher_output_concentrate, dtype: float64

# %%
data_train = data_train[data_train['rougher_output_concentrate']>30]

# %%
data_analysis(data_train['final_output_concentrate'])
# Out:
# count    12740.000000
# mean        68.554925
# std          6.597131
# min          0.000000
# 25%         67.556658
# 50%         69.213556
# 75%         71.031082
# max         80.210644
# Name: final_output_concentrate, dtype: float64

# %%
data_train = data_train[data_train['final_output_concentrate']>40]

# %%
data_train.shape
# Out:
# (12614, 90)

# %%
data_train = data_train.reset_index(drop=True)

# %%
data_test = data_test.reset_index(drop=True)

# %% [markdown]
# Были удалены выбросы по суммарным концентрациям веществ. Процент потери данных обучающей выборки составил 3,6%.

# %%
data_test.shape
# Out:
# (5272, 54)

# %% [markdown]
# Процент потери данных в тестовой выборке - 0.2%.

# %% [markdown]
# После очистки данных удалим столбцы с сумарными концентрациями из выборок, так как они не пригодятся при моделировании.

# %%
data_train = data_train.drop(['rougher_input_feed', 'rougher_output_concentrate','final_output_concentrate'], axis=1)
                             
data_test = data_test.drop(['rougher_input_feed_test'], axis=1)

# %% [markdown]
# <div class="alert alert-info">
# <b> ВЫВОД:</b>
# На данном этапе проведен исследовательский анализ данных.
#
# 1. Изучено концентрации металлов (Au, Ag, Pb) на различных этапах. Сделаны следующие выводы:
#    - концентрация золота растет, достигает максимума к концу технологического процесса
#    - концентрация серебра увеличивается после флотации, а затем уменьшается от этапа к этапу
#    - доля свинца в руде растет до первичной очистки, затем стабилизируется
#    - есть данные с нулевыми концентрациями веществ
#
# 2. Проведено сравнение распределения размеров гранул сырья на обучающей и тестовой выборках.
# Сделан вывод о том, что распределения схожи, выводы после моделирования должны быть корректными.
#
# 3. Проведено исследование суммарной концентрации всех веществ на разных стадиях. Выводы:
#     - есть данные с нулевыми или около нулевыми суммарными концентрациями веществ
#     - присутсвуют выбросы по имеющимся данным
#     - нулевые значения и выбросы удалены, поскольку это может исказить результат работы будущей модели.
#
# Данные исследованы, следующий этап - непосредственно моделирование.
#
#
# </div>

# %% [markdown]
# ## Модель

# %% [markdown]
# Нужно спрогнозировать сразу две величины:
# - эффективность обогащения чернового концентрата rougher.output.recovery
# - эффективность обогащения финального концентрата final.output.recovery

# %% [markdown]
# ### Подготовка признаков и целевых значений

# %% [markdown]
# Создадим набор обучающих и тестовых признаков для rougher.output.recovery, сформируем таргеты.

# %%
TARGETS = ['rougher.output.recovery', 'final.output.recovery']
FEATURES = data_test.columns.drop(['date'])

# %%
features_train = data_train[FEATURES]
target_train = data_train[TARGETS]

# %%
features_test = data_test[FEATURES]

# %% [markdown]
# Целевые значения для тестовой выборки подтянем из полной выборки, используя столбец с признаком "дата".

# %%
test_date = data_test['date']

# %%
target_test = data_full.query('date in @test_date')[['rougher.output.recovery', 'final.output.recovery']].reset_index(drop=True)

# %%
features_train.head()
# Out:
#    primary_cleaner.input.sulfate  primary_cleaner.input.depressant  \
# 0                     127.092003                         10.128295
# 1                     125.629232                         10.296251
# 2                     123.819808                         11.316280
# 3                     122.270188                         11.322140
# 4                     117.988169                         11.913613
#
#    primary_cleaner.input.feed_size  primary_cleaner.input.xanthate  \
# 0                             7.25                        0.988759
# 1                             7.25                        1.002663
# 2                             7.25                        0.991265
# 3                             7.25                        0.996739
# 4                             7.25                        1.009869
#
#    primary_cleaner.state.floatbank8_a_air  \
# 0                             1549.775757
# 1                             1576.166671
# ...

# %%
features_test.head()
# Out:
#    primary_cleaner.input.sulfate  primary_cleaner.input.depressant  \
# 0                     210.800909                         14.993118
# 1                     215.392455                         14.987471
# 2                     215.259946                         12.884934
# 3                     215.336236                         12.006805
# 4                     199.099327                         10.682530
#
#    primary_cleaner.input.feed_size  primary_cleaner.input.xanthate  \
# 0                         8.080000                        1.005021
# 1                         8.080000                        0.990469
# 2                         7.786667                        0.996043
# 3                         7.640000                        0.863514
# 4                         7.530000                        0.805575
#
#    primary_cleaner.state.floatbank8_a_air  \
# 0                             1398.981301
# 1                             1398.777912
# ...

# %%
target_train.head()
# Out:
#    rougher.output.recovery  final.output.recovery
# 0                87.107763              70.541216
# 1                86.843261              69.266198
# 2                86.842308              68.116445
# 3                87.226430              68.347543
# 4                86.688794              66.927016

# %%
target_test.head()
# Out:
#    rougher.output.recovery  final.output.recovery
# 0                89.993421              70.273583
# 1                88.089657              68.910432
# 2                88.412756              68.143213
# 3                87.360133              67.776393
# 4                83.236367              61.467078

# %% [markdown]
# ### Функция вычисления целевой метрики sMAPE

# %% [markdown]
# Создадим функцию для вычисления итоговой sMAPE

# %%
def smape(target, predictions):
    smape = (2*(abs(target - predictions)) / (abs(target) + abs(predictions))).sum()*100/len(target)
    return smape

# %%
def smape_score(target, predictions):
    target_rougher = target['rougher.output.recovery']
    target_final = target['final.output.recovery']
    
    
    predictions_rougher = predictions[:, 0]
    predictions_final =  predictions[:, 1]
    
    smape_rougher = smape(target_rougher, predictions_rougher) 
    smape_final = smape(target_final, predictions_final) 
    
    final_smape_score = 0.25*smape_rougher + 0.75*smape_final
    
    return final_smape_score

# %%
smape_calculation = make_scorer(smape_score, greater_is_better=False)

# %% [markdown]
# ### Подбор наилучшей модели на обучающей выборке

# %% [markdown]
# Обучим разные модели и оценим их качество кросс-валидацией. Выберем лучшую модель и проверим её на тестовой выборке.Используем GridSearchCV и RandomizedSearchCV для подбора оптимальных гиперпараметров модели, в эти методы встроена кросс-валидация.

# %%
#масштабирование признаков

scaler = StandardScaler()
scaler.fit(features_train) 
features_train = scaler.transform(features_train)
features_test = scaler.transform(features_test)

# %% [markdown]
# #### Модель решающего дерева

# %%
# %%time
model = DecisionTreeRegressor(random_state=12)

param_grid = {'max_depth': range(2, 11), 'min_samples_split': [2,3,5], 'min_samples_leaf': [1,3,5]}

dt = RandomizedSearchCV(model, param_grid, scoring = smape_calculation, cv=5, random_state=12)
dt.fit(features_train, target_train)
dt_best = dt.best_estimator_

print('наилучшее значение smape для решающего дерева:', abs(dt.best_score_),'наилучшие параметры:', dt.best_params_)
# Out:
# наилучшее значение smape для решающего дерева: 8.865287422842382 наилучшие параметры: {'min_samples_split': 2, 'min_samples_leaf': 3, 'max_depth': 3}
# CPU times: total: 24 s
# Wall time: 29.9 s

# %% [markdown]
# #### Модель случайного леса

# %%
# %%time
model = RandomForestRegressor(n_jobs = -1, random_state=12)

param_grid = {'n_estimators': range(40,76,5), 'max_depth': [3, 5, 7]}

rf = RandomizedSearchCV(model, param_grid, scoring = smape_calculation, cv=5)
rf.fit(features_train, target_train)
rf_best = rf.best_estimator_
print('наилучшее значение smape для модели случайного леса:', abs(rf.best_score_),'наилучшие параметры:', rf.best_params_)
# Out:
# наилучшее значение smape для модели случайного леса: 8.262987720163533 наилучшие параметры: {'n_estimators': 75, 'max_depth': 5}
# CPU times: total: 1min 6s
# Wall time: 7min 16s

# %% [markdown]
# #### Модель Лассо

# %%
# %%time
model = Lasso(random_state=12)

param_grid = {'alpha': [0.15, 0.2, 0.25, 0.3],
             'max_iter': range(500, 1200, 50),
             'selection': ['cyclic', 'random']}

lasso = GridSearchCV(model, param_grid, scoring = smape_calculation, cv=5)
lasso.fit(features_train, target_train)
lasso_best = lasso.best_estimator_

print('наилучшее значение smape для модели Лассо:', abs(lasso.best_score_),'наилучшие параметры:', lasso.best_params_)
# Out:
# наилучшее значение smape для модели Лассо: 8.18806323886228 наилучшие параметры: {'alpha': 0.3, 'max_iter': 500, 'selection': 'cyclic'}
# CPU times: total: 2min 14s
# Wall time: 1min 7s

# %% [markdown]
# #### Ридж регрессия

# %%
# %%time
model = Ridge(random_state=12)

param_grid = {'alpha': [ 0.05, 0.07, 1, 1.5, 2], 
              'solver': ['auto', 'sag', 'saga']
              }

ridge = GridSearchCV(model, param_grid, scoring = smape_calculation, cv=5)
ridge.fit(features_train, target_train)
ridge_best = ridge.best_estimator_
print('наилучшее значение smape для модели Ридж:', abs(ridge.best_score_),'наилучшие параметры:', ridge.best_params_)
# Out:
# наилучшее значение smape для модели Ридж: 9.628223899088894 наилучшие параметры: {'alpha': 2, 'solver': 'saga'}
# CPU times: total: 1min 25s
# Wall time: 1min 14s

# %% [markdown]
# Наилучшие показатели метрики sMAPE у модели Лассо. Оценим вменяемость модели.

# %% [markdown]
# #### Dummy регрессор

# %% [markdown]
# Проверим модель на адекватность, сравнив ее показатель метрики sMAPE с дамми регрессором, предсказывающим всегда медианное значение.

# %%
model_dummy = DummyRegressor(strategy = "median")
dummy_score = pd.Series(cross_val_score(model_dummy, features_train, target_train, scoring=smape_calculation, cv=5)).mean()

print(abs(dummy_score))
# Out:
# 9.36908188483261

# %% [markdown]
# sMAPE наилучшей модели на обучающих данных = 8,19
#
# sMAPE дамми регрессора на обучающих данных = 9,37
#
# Модель прошла проверку на адекватность. Используем ее на тестовых данных.

# %% [markdown]
# #### Проверка выбранной модели на тестовых данных

# %%
predictions_test = lasso_best.predict(features_test)
score_test = smape_score(target_test, predictions_test)
print('Значение SMAPE наилучшей модели на тестовой выборке:', abs(score_test))
# Out:
# Значение SMAPE наилучшей модели на тестовой выборке: 8.549394974255977

# %% [markdown]
# Снова сравним полученное значение с метрикой sMAPE дамми регрессора на тестовых данных.

# %%
model_dummy = DummyRegressor(strategy = "median")
model_dummy.fit(features_train, target_train)
predictions_test = model_dummy.predict(features_test)
score_test_dummy = smape_score(target_test, predictions_test)
print('Значение SMAPE dummy:', abs(score_test_dummy))
# Out:
# Значение SMAPE dummy: 9.436611408852823

# %% [markdown]
# Показатель полученной модели значительно лучше показателя константной модели. Полученный прототип можно считать удачным.

# %% [markdown]
# <div class="alert alert-info">
# <b> ВЫВОД:</b>
# На данном этапе выполнены следующие шаги:
#
# 1. Подготовлены данные для моделирования: удалены лишние признаки из обучающей и тестовой выборок,
#     выделены целевые значения для обучающей и тестовой части.
#
# 2. Создана функция расчета кастомизированной метрики качества модели
#
# 3. Проведено моделирование при использовании моделей решающего дерева, случайного леса, Лассо и Ридж регрессии.
# Произведен подбор гиперпараметров и оценка при помощи модели с использованием кросс-валидации.
#
# 4. Моделью, показавшей наилучший результат sMAPE стала модель случайного леса с
# фиксированным количеством деревьев и максимальной глубиной.
#
# 5. Произведена оценка вменяемости выбранной модели, модель успешно прошла проверку.
#
# 6. Модель проверена на тестовой выборке.
#
# </div>

# %% [markdown]
# ## Итоговый вывод

# %% [markdown]
# Задачей проекта была подготовка прототипа модели машинного обучения предсказания коэффициент восстановления золота из золотосодержащей руды для оптимизации работы промышленного предприятия.
#
# В ходе работы были сделаны следующие шаги:
#  - изучены данные и выявлены основные закономерности
#  - проведена предварительная обработка данных (заполнены пропуски, удалены выбросы, проверено наличие явных дубликатов)
#  - проведен исследовательский анализ имеющихся данных, сделаны значимые выводы
#  - данные подготовлены для моделирования
#  - введена кастомизированная целевая метрика оценки качества моделей
#  - проведено моделирование с использованием различных моделей регрессии, осуществлен подбор гиперпараметров, оценка качества с использованием целевой метрики и применением кросс-валидации
#  - выбрана наилучшая модель - модель Лассо
#  - проведена оценка качества модели на тестовых данных
#  - модель прошла проверку на вменяемость
#
#  Прототип модели построен успешно. Удалось достичь показателя sMAPE = 8.55 на тестовой выборке.

# %% [markdown]
# ## Чек-лист готовности проекта

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке выполнения
# - [x]  Выполнен шаг 1: данные подготовлены
#     - [x]  Проверена формула вычисления эффективности обогащения
#     - [x]  Проанализированы признаки, недоступные в тестовой выборке
#     - [x]  Проведена предобработка данных
# - [x]  Выполнен шаг 2: данные проанализированы
#     - [x]  Исследовано изменение концентрации элементов на каждом этапе
#     - [x]  Проанализированы распределения размеров гранул на обучающей и тестовой выборках
#     - [x]  Исследованы суммарные концентрации
# - [x]  Выполнен шаг 3: построена модель прогнозирования
#     - [x]  Написана функция для вычисления итогового *sMAPE*
#     - [x]  Обучено и проверено несколько моделей
#     - [x]  Выбрана лучшая модель, её качество проверено на тестовой выборке
